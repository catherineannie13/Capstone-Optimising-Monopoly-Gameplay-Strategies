# %%
import random

# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Player.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Street.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Utility.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Station.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Chance.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Tax.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Go.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Jail.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\FreeParking.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\GoToJail.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\CommunityChest.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\MonopolyBoard.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Strategy.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\RandomStrategy.py"

# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\MonopolyBoardMCTS.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\Node.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\MCTS.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\State.py"

random.seed(42)

# %%
board = MonopolyBoardMCTS()
player1 = Player('Cat')
player2 = Player('Vlad')

board.add_agent(player1)
board.add_other_player(player2)

# %%
board.play_game(stopping_condition=100)

# %%
state = State()

# %%
state.from_monopoly_board(board)

# %%
state.rounds, state.agent, state.other_players, state.properties, state.stations, state.utilities
# Out:
# (100,
#  ['Cat', 27, 94.99999999999999, False, False, 3, False, 0, 2],
#  [['Vlad', 13, 70.0, False, False, 9, False, 0, 1]],
#  [[None, 0, False, False],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   ['Vlad', 0, False, False],
#   ['Vlad', 0, False, False],
#   ['Vlad', 0, False, True],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   ['Vlad', 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False],
#   [None, 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False],
#   [None, 0, False, False],
#   ['Vlad', 0, False, True],
#   ['Vlad', 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False]],
#  [['Cat', False], ['Cat', False], ['Vlad', False], [None, False]],
#  [['Cat', False], ['Vlad', False]])

# %%
new_board = state.to_monopoly_board()

# %%
new_board.players, board.players
# Out:
# ([Player Cat is currently as position 27 on the board, with $95.0.
#    They hold the following properties: ['The Strand', 'Fleet Street', 'Trafalgar Square', 'Coventry Street', 'Piccadilly', 'Park Lane', 'Mayfair'].
#    They hold the following stations: ["King's Cross Station", 'Marylebone Station']
#    They hold the following utilities: ['Electric Company']
#    The player has 0 houses and 0 hotels
#    The player is currently not in jail.,
#   Player Vlad is currently as position 13 on the board, with $70.0.
#    They hold the following properties: ['Pall Mall', 'Whitehall', 'Northumberland Avenue', 'Vine Street', 'Oxford Street', 'Bond Street'].
#    They hold the following stations: ['Fenchurch St. Station']
#    They hold the following utilities: ['Water Works']
#    The player has 0 houses and 0 hotels
#    The player is currently not in jail.],
#  [Player Cat is currently as position 27 on the board, with $95.0.
#    They hold the following properties: ['Trafalgar Square', 'Coventry Street', 'Mayfair', 'Piccadilly', 'The Strand', 'Fleet Street', 'Park Lane'].
#    They hold the following stations: ["King's Cross Station", 'Marylebone Station']
#    They hold the following utilities: ['Electric Company']
#    The player has 0 houses and 0 hotels
#    The player is currently not in jail.,
#   Player Vlad is currently as position 13 on the board, with $70.0.
#    They hold the following properties: ['Pall Mall', 'Vine Street', 'Bond Street', 'Northumberland Avenue', 'Oxford Street', 'Whitehall'].
#    They hold the following stations: ['Fenchurch St. Station']
#    They hold the following utilities: ['Water Works']
#    The player has 0 houses and 0 hotels
#    The player is currently not in jail.])

# %%
for i in range(len(board.properties)):
    print(board.properties[i], new_board.properties[i], '\n')
# Out:
# Old Kent Road is one of the 2 properties in the brown set located at position 1 on the Monopoly board
#  and can be purchased for $60 with a house price of $50. Rent prices are as follows:
#  Rent: 2
#  Double rent: 4
#  Rent 1 house: 10
#  Rent 2 houses: 30
#  Rent 3 houses: 90
#  Rent 4 houses: 160
#  Rent hotel: 250
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Old Kent Road is one of the 2 properties in the brown set located at position 1 on the Monopoly board
#  and can be purchased for $60 with a house price of $50. Rent prices are as follows:
#  Rent: 2
#  Double rent: 4
#  Rent 1 house: 10
#  Rent 2 houses: 30
#  Rent 3 houses: 90
#  Rent 4 houses: 160
#  Rent hotel: 250
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Whitechapel Road is one of the 2 properties in the brown set located at position 3 on the Monopoly board
#  and can be purchased for $60 with a house price of $50. Rent prices are as follows:
#  Rent: 4
#  Double rent: 8
#  Rent 1 house: 20
#  Rent 2 houses: 60
#  Rent 3 houses: 180
#  Rent 4 houses: 320
#  Rent hotel: 450
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Whitechapel Road is one of the 2 properties in the brown set located at position 3 on the Monopoly board
#  and can be purchased for $60 with a house price of $50. Rent prices are as follows:
#  Rent: 4
#  Double rent: 8
#  Rent 1 house: 20
#  Rent 2 houses: 60
#  Rent 3 houses: 180
#  Rent 4 houses: 320
#  Rent hotel: 450
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# The Angel Islington is one of the 3 properties in the lightblue set located at position 6 on the Monopoly board
#  and can be purchased for $100 with a house price of $50. Rent prices are as follows:
#  Rent: 6
#  Double rent: 12
#  Rent 1 house: 30
#  Rent 2 houses: 90
#  Rent 3 houses: 270
#  Rent 4 houses: 400
#  Rent hotel: 550
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. The Angel Islington is one of the 3 properties in the lightblue set located at position 6 on the Monopoly board
#  and can be purchased for $100 with a house price of $50. Rent prices are as follows:
#  Rent: 6
#  Double rent: 12
#  Rent 1 house: 30
#  Rent 2 houses: 90
#  Rent 3 houses: 270
#  Rent 4 houses: 400
#  Rent hotel: 550
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Euston Road is one of the 3 properties in the lightblue set located at position 8 on the Monopoly board
#  and can be purchased for $100 with a house price of $50. Rent prices are as follows:
#  Rent: 6
#  Double rent: 12
#  Rent 1 house: 30
#  Rent 2 houses: 90
#  Rent 3 houses: 270
#  Rent 4 houses: 400
#  Rent hotel: 550
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Euston Road is one of the 3 properties in the lightblue set located at position 8 on the Monopoly board
#  and can be purchased for $100 with a house price of $50. Rent prices are as follows:
#  Rent: 6
#  Double rent: 12
#  Rent 1 house: 30
#  Rent 2 houses: 90
#  Rent 3 houses: 270
#  Rent 4 houses: 400
#  Rent hotel: 550
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Pentonville Road is one of the 3 properties in the lightblue set located at position 9 on the Monopoly board
#  and can be purchased for $120 with a house price of $50. Rent prices are as follows:
#  Rent: 8
#  Double rent: 16
#  Rent 1 house: 40
#  Rent 2 houses: 100
#  Rent 3 houses: 300
#  Rent 4 houses: 450
#  Rent hotel: 600
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Pentonville Road is one of the 3 properties in the lightblue set located at position 9 on the Monopoly board
#  and can be purchased for $120 with a house price of $50. Rent prices are as follows:
#  Rent: 8
#  Double rent: 16
#  Rent 1 house: 40
#  Rent 2 houses: 100
#  Rent 3 houses: 300
#  Rent 4 houses: 450
#  Rent hotel: 600
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Pall Mall is one of the 3 properties in the pink set located at position 11 on the Monopoly board
#  and can be purchased for $140 with a house price of $100. Rent prices are as follows:
#  Rent: 10
#  Double rent: 20
#  Rent 1 house: 50
#  Rent 2 houses: 150
#  Rent 3 houses: 450
#  Rent 4 houses: 625
#  Rent hotel: 750
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels. Pall Mall is one of the 3 properties in the pink set located at position 11 on the Monopoly board
#  and can be purchased for $140 with a house price of $100. Rent prices are as follows:
#  Rent: 10
#  Double rent: 20
#  Rent 1 house: 50
#  Rent 2 houses: 150
#  Rent 3 houses: 450
#  Rent 4 houses: 625
#  Rent hotel: 750
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels.
#
# Whitehall is one of the 3 properties in the pink set located at position 13 on the Monopoly board
#  and can be purchased for $140 with a house price of $100. Rent prices are as follows:
#  Rent: 10
#  Double rent: 20
#  Rent 1 house: 50
#  Rent 2 houses: 150
#  Rent 3 houses: 450
#  Rent 4 houses: 625
#  Rent hotel: 750
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels. Whitehall is one of the 3 properties in the pink set located at position 13 on the Monopoly board
#  and can be purchased for $140 with a house price of $100. Rent prices are as follows:
#  Rent: 10
#  Double rent: 20
#  Rent 1 house: 50
#  Rent 2 houses: 150
#  Rent 3 houses: 450
#  Rent 4 houses: 625
#  Rent hotel: 750
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels.
#
# Northumberland Avenue is one of the 3 properties in the pink set located at position 14 on the Monopoly board
#  and can be purchased for $160 with a house price of $100. Rent prices are as follows:
#  Rent: 12
#  Double rent: 24
#  Rent 1 house: 60
#  Rent 2 houses: 180
#  Rent 3 houses: 500
#  Rent 4 houses: 700
#  Rent hotel: 900
#  The property is currently owned by Vlad, is mortgaged and has 0 houses and 0 hotels. Northumberland Avenue is one of the 3 properties in the pink set located at position 14 on the Monopoly board
#  and can be purchased for $160 with a house price of $100. Rent prices are as follows:
#  Rent: 12
#  Double rent: 24
#  Rent 1 house: 60
#  Rent 2 houses: 180
#  Rent 3 houses: 500
#  Rent 4 houses: 700
#  Rent hotel: 900
#  The property is currently owned by Vlad, is mortgaged and has 0 houses and 0 hotels.
#
# Bow Street is one of the 3 properties in the orange set located at position 16 on the Monopoly board
#  and can be purchased for $180 with a house price of $100. Rent prices are as follows:
#  Rent: 14
#  Double rent: 28
#  Rent 1 house: 70
#  Rent 2 houses: 200
#  Rent 3 houses: 550
#  Rent 4 houses: 750
#  Rent hotel: 950
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Bow Street is one of the 3 properties in the orange set located at position 16 on the Monopoly board
#  and can be purchased for $180 with a house price of $100. Rent prices are as follows:
#  Rent: 14
#  Double rent: 28
#  Rent 1 house: 70
#  Rent 2 houses: 200
#  Rent 3 houses: 550
#  Rent 4 houses: 750
#  Rent hotel: 950
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Marlborough Street is one of the 3 properties in the orange set located at position 18 on the Monopoly board
#  and can be purchased for $180 with a house price of $100. Rent prices are as follows:
#  Rent: 14
#  Double rent: 28
#  Rent 1 house: 70
#  Rent 2 houses: 200
#  Rent 3 houses: 550
#  Rent 4 houses: 750
#  Rent hotel: 950
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Marlborough Street is one of the 3 properties in the orange set located at position 18 on the Monopoly board
#  and can be purchased for $180 with a house price of $100. Rent prices are as follows:
#  Rent: 14
#  Double rent: 28
#  Rent 1 house: 70
#  Rent 2 houses: 200
#  Rent 3 houses: 550
#  Rent 4 houses: 750
#  Rent hotel: 950
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Vine Street is one of the 3 properties in the orange set located at position 19 on the Monopoly board
#  and can be purchased for $200 with a house price of $100. Rent prices are as follows:
#  Rent: 16
#  Double rent: 32
#  Rent 1 house: 80
#  Rent 2 houses: 220
#  Rent 3 houses: 600
#  Rent 4 houses: 800
#  Rent hotel: 1000
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels. Vine Street is one of the 3 properties in the orange set located at position 19 on the Monopoly board
#  and can be purchased for $200 with a house price of $100. Rent prices are as follows:
#  Rent: 16
#  Double rent: 32
#  Rent 1 house: 80
#  Rent 2 houses: 220
#  Rent 3 houses: 600
#  Rent 4 houses: 800
#  Rent hotel: 1000
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels.
#
# The Strand is one of the 3 properties in the red set located at position 21 on the Monopoly board
#  and can be purchased for $220 with a house price of $150. Rent prices are as follows:
#  Rent: 18
#  Double rent: 36
#  Rent 1 house: 90
#  Rent 2 houses: 250
#  Rent 3 houses: 700
#  Rent 4 houses: 875
#  Rent hotel: 1050
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels. The Strand is one of the 3 properties in the red set located at position 21 on the Monopoly board
#  and can be purchased for $220 with a house price of $150. Rent prices are as follows:
#  Rent: 18
#  Double rent: 36
#  Rent 1 house: 90
#  Rent 2 houses: 250
#  Rent 3 houses: 700
#  Rent 4 houses: 875
#  Rent hotel: 1050
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels.
#
# Fleet Street is one of the 3 properties in the red set located at position 23 on the Monopoly board
#  and can be purchased for $220 with a house price of $150. Rent prices are as follows:
#  Rent: 18
#  Double rent: 36
#  Rent 1 house: 90
#  Rent 2 houses: 250
#  Rent 3 houses: 700
#  Rent 4 houses: 875
#  Rent hotel: 1050
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels. Fleet Street is one of the 3 properties in the red set located at position 23 on the Monopoly board
#  and can be purchased for $220 with a house price of $150. Rent prices are as follows:
#  Rent: 18
#  Double rent: 36
#  Rent 1 house: 90
#  Rent 2 houses: 250
#  Rent 3 houses: 700
#  Rent 4 houses: 875
#  Rent hotel: 1050
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels.
#
# Trafalgar Square is one of the 3 properties in the red set located at position 24 on the Monopoly board
#  and can be purchased for $240 with a house price of $150. Rent prices are as follows:
#  Rent: 20
#  Double rent: 40
#  Rent 1 house: 100
#  Rent 2 houses: 300
#  Rent 3 houses: 750
#  Rent 4 houses: 925
#  Rent hotel: 1100
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels. Trafalgar Square is one of the 3 properties in the red set located at position 24 on the Monopoly board
#  and can be purchased for $240 with a house price of $150. Rent prices are as follows:
#  Rent: 20
#  Double rent: 40
#  Rent 1 house: 100
#  Rent 2 houses: 300
#  Rent 3 houses: 750
#  Rent 4 houses: 925
#  Rent hotel: 1100
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels.
#
# Leicester Square is one of the 3 properties in the yellow set located at position 26 on the Monopoly board
#  and can be purchased for $260 with a house price of $150. Rent prices are as follows:
#  Rent: 22
#  Double rent: 44
#  Rent 1 house: 110
#  Rent 2 houses: 330
#  Rent 3 houses: 800
#  Rent 4 houses: 975
#  Rent hotel: 1150
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Leicester Square is one of the 3 properties in the yellow set located at position 26 on the Monopoly board
#  and can be purchased for $260 with a house price of $150. Rent prices are as follows:
#  Rent: 22
#  Double rent: 44
#  Rent 1 house: 110
#  Rent 2 houses: 330
#  Rent 3 houses: 800
#  Rent 4 houses: 975
#  Rent hotel: 1150
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Coventry Street is one of the 3 properties in the yellow set located at position 27 on the Monopoly board
#  and can be purchased for $260 with a house price of $150. Rent prices are as follows:
#  Rent: 22
#  Double rent: 44
#  Rent 1 house: 110
#  Rent 2 houses: 330
#  Rent 3 houses: 800
#  Rent 4 houses: 975
#  Rent hotel: 1150
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels. Coventry Street is one of the 3 properties in the yellow set located at position 27 on the Monopoly board
#  and can be purchased for $260 with a house price of $150. Rent prices are as follows:
#  Rent: 22
#  Double rent: 44
#  Rent 1 house: 110
#  Rent 2 houses: 330
#  Rent 3 houses: 800
#  Rent 4 houses: 975
#  Rent hotel: 1150
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels.
#
# Piccadilly is one of the 3 properties in the yellow set located at position 29 on the Monopoly board
#  and can be purchased for $280 with a house price of $150. Rent prices are as follows:
#  Rent: 24
#  Double rent: 48
#  Rent 1 house: 120
#  Rent 2 houses: 360
#  Rent 3 houses: 850
#  Rent 4 houses: 1025
#  Rent hotel: 1200
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels. Piccadilly is one of the 3 properties in the yellow set located at position 29 on the Monopoly board
#  and can be purchased for $280 with a house price of $150. Rent prices are as follows:
#  Rent: 24
#  Double rent: 48
#  Rent 1 house: 120
#  Rent 2 houses: 360
#  Rent 3 houses: 850
#  Rent 4 houses: 1025
#  Rent hotel: 1200
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels.
#
# Regent Street is one of the 3 properties in the green set located at position 31 on the Monopoly board
#  and can be purchased for $300 with a house price of $200. Rent prices are as follows:
#  Rent: 26
#  Double rent: 52
#  Rent 1 house: 130
#  Rent 2 houses: 390
#  Rent 3 houses: 900
#  Rent 4 houses: 1100
#  Rent hotel: 1275
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels. Regent Street is one of the 3 properties in the green set located at position 31 on the Monopoly board
#  and can be purchased for $300 with a house price of $200. Rent prices are as follows:
#  Rent: 26
#  Double rent: 52
#  Rent 1 house: 130
#  Rent 2 houses: 390
#  Rent 3 houses: 900
#  Rent 4 houses: 1100
#  Rent hotel: 1275
#  The property is currently owned by no-one, is not mortgaged and has 0 houses and 0 hotels.
#
# Oxford Street is one of the 3 properties in the green set located at position 32 on the Monopoly board
#  and can be purchased for $300 with a house price of $200. Rent prices are as follows:
#  Rent: 26
#  Double rent: 52
#  Rent 1 house: 130
#  Rent 2 houses: 390
#  Rent 3 houses: 900
#  Rent 4 houses: 1100
#  Rent hotel: 1275
#  The property is currently owned by Vlad, is mortgaged and has 0 houses and 0 hotels. Oxford Street is one of the 3 properties in the green set located at position 32 on the Monopoly board
#  and can be purchased for $300 with a house price of $200. Rent prices are as follows:
#  Rent: 26
#  Double rent: 52
#  Rent 1 house: 130
#  Rent 2 houses: 390
#  Rent 3 houses: 900
#  Rent 4 houses: 1100
#  Rent hotel: 1275
#  The property is currently owned by Vlad, is mortgaged and has 0 houses and 0 hotels.
#
# Bond Street is one of the 3 properties in the green set located at position 34 on the Monopoly board
#  and can be purchased for $320 with a house price of $200. Rent prices are as follows:
#  Rent: 28
#  Double rent: 56
#  Rent 1 house: 150
#  Rent 2 houses: 450
#  Rent 3 houses: 1000
#  Rent 4 houses: 1200
#  Rent hotel: 1400
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels. Bond Street is one of the 3 properties in the green set located at position 34 on the Monopoly board
#  and can be purchased for $320 with a house price of $200. Rent prices are as follows:
#  Rent: 28
#  Double rent: 56
#  Rent 1 house: 150
#  Rent 2 houses: 450
#  Rent 3 houses: 1000
#  Rent 4 houses: 1200
#  Rent hotel: 1400
#  The property is currently owned by Vlad, is not mortgaged and has 0 houses and 0 hotels.
#
# Park Lane is one of the 2 properties in the darkblue set located at position 37 on the Monopoly board
#  and can be purchased for $350 with a house price of $200. Rent prices are as follows:
#  Rent: 35
#  Double rent: 70
#  Rent 1 house: 175
#  Rent 2 houses: 500
#  Rent 3 houses: 1100
#  Rent 4 houses: 1300
#  Rent hotel: 1500
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels. Park Lane is one of the 2 properties in the darkblue set located at position 37 on the Monopoly board
#  and can be purchased for $350 with a house price of $200. Rent prices are as follows:
#  Rent: 35
#  Double rent: 70
#  Rent 1 house: 175
#  Rent 2 houses: 500
#  Rent 3 houses: 1100
#  Rent 4 houses: 1300
#  Rent hotel: 1500
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels.
#
# Mayfair is one of the 2 properties in the darkblue set located at position 39 on the Monopoly board
#  and can be purchased for $400 with a house price of $200. Rent prices are as follows:
#  Rent: 50
#  Double rent: 100
#  Rent 1 house: 200
#  Rent 2 houses: 600
#  Rent 3 houses: 1400
#  Rent 4 houses: 1700
#  Rent hotel: 2000
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels. Mayfair is one of the 2 properties in the darkblue set located at position 39 on the Monopoly board
#  and can be purchased for $400 with a house price of $200. Rent prices are as follows:
#  Rent: 50
#  Double rent: 100
#  Rent 1 house: 200
#  Rent 2 houses: 600
#  Rent 3 houses: 1400
#  Rent 4 houses: 1700
#  Rent hotel: 2000
#  The property is currently owned by Cat, is not mortgaged and has 0 houses and 0 hotels.

# %%
for i in range(len(board.stations)):
    print(board.stations[i], new_board.stations[i], '\n')
# Out:
# King's Cross Station is a station located at position 5 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by Cat and is not mortgaged. King's Cross Station is a station located at position 5 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by Cat and is not mortgaged.
#
# Marylebone Station is a station located at position 15 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by Cat and is not mortgaged. Marylebone Station is a station located at position 15 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by Cat and is not mortgaged.
#
# Fenchurch St. Station is a station located at position 25 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by Vlad and is not mortgaged. Fenchurch St. Station is a station located at position 25 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by Vlad and is not mortgaged.
#
# Liverpool St. Station is a station located at position 35 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by no-one and is not mortgaged. Liverpool St. Station is a station located at position 35 on the Monopoly board that can be purchased for 200.
#  Rent is as follows:
#  Rent if a single station is owned: 25
#  Rent if two stations are owned: 50
#  Rent if three stations are owned: 100
#  Rent if four stations are owned: 200
#  This property is currently owned by no-one and is not mortgaged.

# %%
for i in range(len(board.utilities)):
    print(board.utilities[i], new_board.utilities[i], '\n')
# Out:
# Electric Company is a utility located at position 12 on the Monopoly board that can be purchased for 150.
#  If a player owns a single utility, they must be paid 4 multiplied by the dice roll in rent.
#  If a player owns both utilities, they must by paid 10 multiplied by the dice roll in rent.
#  This property is currently owned by Cat and is not mortgaged. Electric Company is a utility located at position 12 on the Monopoly board that can be purchased for 150.
#  If a player owns a single utility, they must be paid 4 multiplied by the dice roll in rent.
#  If a player owns both utilities, they must by paid 10 multiplied by the dice roll in rent.
#  This property is currently owned by Cat and is not mortgaged.
#
# Water Works is a utility located at position 28 on the Monopoly board that can be purchased for 150.
#  If a player owns a single utility, they must be paid 4 multiplied by the dice roll in rent.
#  If a player owns both utilities, they must by paid 10 multiplied by the dice roll in rent.
#  This property is currently owned by Vlad and is not mortgaged. Water Works is a utility located at position 28 on the Monopoly board that can be purchased for 150.
#  If a player owns a single utility, they must be paid 4 multiplied by the dice roll in rent.
#  If a player owns both utilities, they must by paid 10 multiplied by the dice roll in rent.
#  This property is currently owned by Vlad and is not mortgaged.

# %%
state1 = State()

# %%
state1.from_monopoly_board(board)

# %%
state1.rounds, state1.agent, state1.other_players, state1.properties, state1.stations, state1.utilities
# Out:
# (100,
#  ['Cat', 27, 94.99999999999999, False, False, 3, False, 0, 2],
#  [['Vlad', 13, 70.0, False, False, 9, False, 0, 1]],
#  [[None, 0, False, False],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   ['Vlad', 0, False, False],
#   ['Vlad', 0, False, False],
#   ['Vlad', 0, False, True],
#   [None, 0, False, False],
#   [None, 0, False, False],
#   ['Vlad', 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False],
#   [None, 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False],
#   [None, 0, False, False],
#   ['Vlad', 0, False, True],
#   ['Vlad', 0, False, False],
#   ['Cat', 0, False, False],
#   ['Cat', 0, False, False]],
#  [['Cat', False], ['Cat', False], ['Vlad', False], [None, False]],
#  [['Cat', False], ['Vlad', False]])

# %%
vars(state) == vars(state1)
# Out:
# True

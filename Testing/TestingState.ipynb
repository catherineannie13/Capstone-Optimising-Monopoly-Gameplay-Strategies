# %% [markdown]
# ## Imports

# %%
import random

# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Player.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Street.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Utility.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Station.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Chance.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Tax.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Go.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Jail.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\FreeParking.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\GoToJail.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\CommunityChest.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\MonopolyBoard.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\Strategy.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\Simulation Classes\\RandomStrategy.py"

# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\MonopolyBoardMCTS.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\Node.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\MCTS.py"
# %run -i "C:\\Users\\cathe\\OneDrive\\Documents\\Capstone - Optimising Monopoly Gameplay Strategies\\MCTS\\State.py"

random.seed(42)

# %% [markdown]
# ## Basic tests

# %%
board = MonopolyBoardMCTS()
player1 = Player('Cat')
player2 = Player('Vlad')

board.add_agent(player1)
board.add_other_player(player2)

# %%
board.play_game(stopping_condition=1000)

# %%
state = State()

# %%
state.from_monopoly_board(board)

# %%
state.rounds, state.agent, state.other_players, state.properties, state.stations, state.utilities

# %%
new_board = state.to_monopoly_board()

# %%
new_board.players, board.players

# %%
for i in range(len(board.properties)):
    print(board.properties[i], new_board.properties[i], '\n')

# %%
for i in range(len(board.stations)):
    print(board.stations[i], new_board.stations[i], '\n')

# %%
for i in range(len(board.utilities)):
    print(board.utilities[i], new_board.utilities[i], '\n')

# %%
state1 = State()

# %%
state1.from_monopoly_board(board)

# %%
state1.rounds, state1.agent, state1.other_players, state1.properties, state1.stations, state1.utilities

# %%
vars(state) == vars(state1)

# %% [markdown]
# ## MCTS with State

# %%
board = MonopolyBoardMCTS()
player1 = Player('Cat')
player2 = Player('Vlad')

board.add_agent(player1)
board.add_other_player(player2)

# %%
root_state = State()
root_state.from_monopoly_board(board)

# %%
mcts = MCTS(root_state, 10000)

# %%
mcts.run_game()
# Out:
# Running MCTS game: 100%|██████████| 1000/1000 [10:38:33<00:00, 38.31s/it]

# %%
mcts.root.state.rounds, len(mcts.best_actions)
# Out:
# (222, 1000)

# %%
mcts.best_actions
# Out:
# ['End turn',
#  'Purchase Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Purchase Regent Street',
#  'Mortgage Regent Street',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Purchase Pentonville Road',
#  'Mortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Regent Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Purchase Coventry Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Coventry Street',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Mortgage Regent Street',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Coventry Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Coventry Street',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'End turn',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Purchase Oxford Street',
#  'Mortgage Pall Mall',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Mortgage Pall Mall',
#  'Mortgage Coventry Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Coventry Street',
#  'Mortgage Regent Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Pentonville Road',
#  'Mortgage Coventry Street',
#  'Unmortgage Coventry Street',
#  'Mortgage Pall Mall',
#  'Mortgage Oxford Street',
#  'Mortgage Coventry Street',
#  'End turn',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Mortgage Regent Street',
#  'End turn',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Coventry Street',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Mortgage Coventry Street',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Regent Street',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Unmortgage Regent Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Regent Street',
#  'End turn',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Regent Street',
#  'Mortgage Pentonville Road',
#  'Mortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Pay 50 to get out of jail',
#  'Mortgage Pall Mall',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Oxford Street',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Regent Street',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Mortgage Regent Street',
#  'Pay 50 to get out of jail',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Coventry Street',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Coventry Street',
#  'Unmortgage Oxford Street',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Pay 50 to get out of jail',
#  'Unmortgage Pentonville Road',
#  'Mortgage Regent Street',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Mortgage Regent Street',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'Mortgage Pall Mall',
#  'Mortgage Coventry Street',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Mortgage Coventry Street',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Mortgage Coventry Street',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Unmortgage Oxford Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Oxford Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Mortgage Regent Street',
#  'Purchase Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Mortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Mortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Oxford Street',
#  'Unmortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Coventry Street',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Regent Street',
#  'Mortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Coventry Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Coventry Street',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Coventry Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'Purchase Water Works',
#  'Mortgage Regent Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Water Works',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage Oxford Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Coventry Street',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Unmortgage Oxford Street',
#  'End turn',
#  'Mortgage Oxford Street',
#  'End turn',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Pay 50 to get out of jail',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'Mortgage Coventry Street',
#  'Unmortgage Water Works',
#  'End turn',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Pay 50 to get out of jail',
#  'Mortgage Water Works',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Water Works',
#  'End turn',
#  'Mortgage Water Works',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Unmortgage Water Works',
#  'End turn',
#  'End turn',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Oxford Street',
#  'End turn',
#  'Mortgage Water Works',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Mortgage Oxford Street',
#  'Pay 50 to get out of jail',
#  'Unmortgage Coventry Street',
#  'Unmortgage Water Works',
#  'Mortgage Water Works',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Mortgage Coventry Street',
#  'End turn',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Water Works',
#  'Mortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Water Works',
#  'Mortgage Oxford Street',
#  'Unmortgage Water Works',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Water Works',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'End turn',
#  'Unmortgage Water Works',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Water Works',
#  'Unmortgage Water Works',
#  'End turn',
#  'Purchase The Angel Islington',
#  'Unmortgage Coventry Street',
#  'Mortgage Pentonville Road',
#  'Mortgage The Angel Islington',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage The Angel Islington',
#  'Mortgage Water Works',
#  'Mortgage Coventry Street',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage The Angel Islington',
#  'Unmortgage Water Works',
#  'Unmortgage Pall Mall',
#  'Unmortgage Coventry Street',
#  'Unmortgage The Angel Islington',
#  'Mortgage The Angel Islington',
#  'Unmortgage The Angel Islington',
#  'Mortgage Coventry Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Mortgage Pall Mall',
#  'Mortgage Water Works',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage The Angel Islington',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Unmortgage Water Works',
#  'Mortgage Coventry Street',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage Water Works',
#  'Pay 50 to get out of jail',
#  'Mortgage Pentonville Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Water Works',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Water Works',
#  'End turn',
#  'End turn',
#  'Unmortgage Water Works',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Water Works',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Pay 50 to get out of jail',
#  'Unmortgage The Angel Islington',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage The Angel Islington',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pentonville Road',
#  'Unmortgage The Angel Islington',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Mortgage The Angel Islington',
#  'Unmortgage The Angel Islington',
#  'Mortgage Pall Mall',
#  'End turn',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Pentonville Road',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage The Angel Islington',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Water Works',
#  'Mortgage Water Works',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'End turn',
#  'Unmortgage Coventry Street',
#  'Mortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage The Angel Islington',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'Unmortgage The Angel Islington',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage The Angel Islington',
#  'Mortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'Unmortgage The Angel Islington',
#  'Mortgage The Angel Islington',
#  'Unmortgage The Angel Islington',
#  'Mortgage The Angel Islington',
#  'Unmortgage The Angel Islington',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Oxford Street',
#  'Unmortgage The Angel Islington',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Water Works',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage The Angel Islington',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Water Works',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Unmortgage Water Works',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Unmortgage Coventry Street',
#  'Unmortgage The Angel Islington',
#  'End turn',
#  'Unmortgage Regent Street',
#  'Mortgage Water Works',
#  'End turn',
#  'End turn',
#  'Mortgage Regent Street',
#  'Unmortgage Water Works',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Regent Street',
#  'Mortgage Pentonville Road',
#  'Mortgage The Angel Islington',
#  'Mortgage Water Works',
#  'Mortgage Coventry Street',
#  'Unmortgage Coventry Street',
#  'Unmortgage The Angel Islington',
#  'Mortgage The Angel Islington',
#  'Mortgage Regent Street',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Water Works',
#  'End turn',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Mortgage The Angel Islington',
#  'Mortgage Water Works',
#  'Unmortgage Pall Mall',
#  'Unmortgage The Angel Islington',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'Unmortgage Coventry Street',
#  'Mortgage Regent Street',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Water Works',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Coventry Street',
#  'Unmortgage Coventry Street',
#  'Mortgage The Angel Islington',
#  'Mortgage Coventry Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Mortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Unmortgage Regent Street',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Pall Mall',
#  'Mortgage Water Works',
#  'Mortgage The Angel Islington',
#  'Unmortgage Water Works',
#  'Mortgage Water Works',
#  'Unmortgage Water Works',
#  'Mortgage Pall Mall',
#  'Unmortgage Coventry Street',
#  'Unmortgage The Angel Islington',
#  'Mortgage The Angel Islington',
#  'Mortgage Coventry Street',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Coventry Street',
#  'Mortgage Water Works',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Coventry Street',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Coventry Street',
#  'Unmortgage Water Works',
#  'Mortgage Pentonville Road',
#  'Mortgage Water Works',
#  'Unmortgage Regent Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Coventry Street',
#  'End turn',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Mortgage Oxford Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Coventry Street',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage The Angel Islington',
#  'Mortgage Regent Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Mortgage Coventry Street',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Oxford Street',
#  'Unmortgage Water Works',
#  'Mortgage Oxford Street',
#  'Unmortgage Oxford Street',
#  'Mortgage Water Works',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'Mortgage The Angel Islington',
#  'Mortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Pentonville Road',
#  'Unmortgage Regent Street',
#  'Unmortgage Water Works',
#  'Mortgage Water Works',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage The Angel Islington',
#  'End turn',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pall Mall',
#  'Mortgage Pentonville Road',
#  'Unmortgage Oxford Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage Regent Street',
#  'Mortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Water Works',
#  'Mortgage Water Works',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Water Works',
#  'End turn',
#  'Mortgage Pentonville Road',
#  'Mortgage Water Works',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Water Works',
#  'Mortgage Oxford Street',
#  'End turn',
#  'Mortgage The Angel Islington',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Pentonville Road',
#  'Mortgage Fenchurch St. Station',
#  'Purchase Whitehall',
#  'Mortgage Water Works',
#  'End turn',
#  'Unmortgage Coventry Street',
#  'Unmortgage The Angel Islington',
#  'Mortgage Coventry Street',
#  'Mortgage Pall Mall',
#  'Mortgage Regent Street',
#  'Mortgage Whitehall',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Whitehall',
#  'Unmortgage Regent Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Whitehall',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Whitehall',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Mortgage Whitehall',
#  'Pay 50 to get out of jail',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'Mortgage The Angel Islington',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'Unmortgage Water Works',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Water Works',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Unmortgage Whitehall',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Water Works',
#  'Mortgage Pentonville Road',
#  'Mortgage Water Works',
#  'Unmortgage Pall Mall',
#  'Unmortgage Water Works',
#  'Mortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage The Angel Islington',
#  'Unmortgage Pentonville Road',
#  'Mortgage Water Works',
#  'End turn',
#  'Unmortgage The Angel Islington',
#  'Mortgage Pentonville Road',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'Mortgage Whitehall',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage Pall Mall',
#  'Mortgage The Angel Islington',
#  'Unmortgage Water Works',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Whitehall',
#  'Mortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Whitehall',
#  'Unmortgage Whitehall',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Water Works',
#  'Unmortgage Water Works',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage Pentonville Road',
#  'Unmortgage The Angel Islington',
#  'Mortgage Whitehall',
#  'Mortgage Pentonville Road',
#  'Mortgage Water Works',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Pentonville Road',
#  'Mortgage Pentonville Road',
#  'Unmortgage Pentonville Road',
#  'Mortgage The Angel Islington',
#  'Unmortgage Water Works',
#  'Mortgage Pentonville Road',
#  'End turn',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Coventry Street',
#  'End turn',
#  'Mortgage Water Works',
#  'Unmortgage Whitehall',
#  'Mortgage Whitehall',
#  'Unmortgage Oxford Street',
#  'Unmortgage Whitehall',
#  'Mortgage Coventry Street',
#  'Mortgage Whitehall',
#  'Mortgage Oxford Street',
#  'Unmortgage Coventry Street',
#  'Unmortgage Pentonville Road',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Regent Street',
#  'Mortgage Pentonville Road',
#  'Mortgage Coventry Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Unmortgage Coventry Street',
#  'Mortgage Coventry Street',
#  'Unmortgage The Angel Islington']

# %%
mcts.root.state.agent
# [agent.name, agent.position, agent.money, agent.bankrupt, agent.in_jail, agent.turns_in_jail, 
# agent.double_rolled, agent.num_doubles, agent.jail_cards]
# Out:
# ['Cat', 36, 175.8699999999999, False, False, 0, False, 2, 0, {}]

# %%
mcts.root.state.other_players
# Out:
# [['Vlad', 29, 24.349999999999966, False, False, 13, False, 0, 0, {}]]

# %%
mcts.root.state.properties
# [prop.owner.name, prop.num_houses, prop.hotel, prop.is_mortgaged]
# Out:
# [['Vlad', 0, False, False],
#  ['Vlad', 1, False, False],
#  ['Cat', 0, False, False],
#  [None, 0, False, False],
#  ['Cat', 0, False, True],
#  ['Cat', 0, False, True],
#  ['Cat', 0, False, True],
#  [None, 0, False, False],
#  [None, 0, False, False],
#  [None, 0, False, False],
#  [None, 0, False, False],
#  ['Vlad', 1, False, False],
#  ['Vlad', 0, False, False],
#  ['Vlad', 0, False, False],
#  [None, 0, False, False],
#  ['Cat', 0, False, True],
#  ['Vlad', 0, False, False],
#  ['Cat', 0, False, True],
#  ['Cat', 0, False, True],
#  [None, 0, False, False],
#  [None, 0, False, False],
#  [None, 0, False, False]]

# %% [markdown]
# ## MCTS with State & Random strategy

# %%
board = MonopolyBoardMCTS()
player1 = Player('Cat')
player2 = Player('Vlad')

board.add_agent(player1)
board.add_other_player(player2)

strategy = RandomStrategy()
board.strategy = strategy

# %%
root_state = State()
root_state.from_monopoly_board(board)

# %%
mcts = MCTS(root_state, 1000)

# %%
mcts.run_game()
# Out:
# Running MCTS game:   6%|▋         | 65/1000 [51:03<12:14:32, 47.14s/it]
# Running MCTS game: 100%|██████████| 1000/1000 [1:35:04<00:00,  5.70s/it]

# %%
mcts.root.state.rounds, len(mcts.best_actions)
# Out:
# (195, 1000)

# %%
mcts.best_actions
# Out:
# ['End turn',
#  'End turn',
#  'End turn',
#  'Purchase Marlborough Street',
#  'Mortgage Marlborough Street',
#  'End turn',
#  'End turn',
#  'Purchase Regent Street',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Marlborough Street',
#  'End turn',
#  'Purchase Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Mortgage Marlborough Street',
#  'End turn',
#  'Unmortgage Regent Street',
#  'End turn',
#  "Purchase King's Cross Station",
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'End turn',
#  'End turn',
#  'Unmortgage Marlborough Street',
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Purchase The Strand',
#  "Unmortgage King's Cross Station",
#  'Mortgage The Strand',
#  "Mortgage King's Cross Station",
#  'Mortgage Marlborough Street',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage The Strand',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Marlborough Street',
#  "Unmortgage King's Cross Station",
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Marlborough Street',
#  'Purchase Oxford Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Oxford Street',
#  "Mortgage King's Cross Station",
#  'Mortgage The Strand',
#  "Unmortgage King's Cross Station",
#  'Unmortgage The Strand',
#  'Unmortgage Regent Street',
#  'Unmortgage Marlborough Street',
#  'Mortgage The Strand',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage The Strand',
#  'Mortgage The Strand',
#  'Unmortgage Oxford Street',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Marlborough Street',
#  'Unmortgage Marlborough Street',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Marlborough Street',
#  'Unmortgage Fenchurch St. Station',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'Purchase Leicester Square',
#  'Mortgage Regent Street',
#  'End turn',
#  'Mortgage Leicester Square',
#  'Unmortgage Marlborough Street',
#  'Unmortgage The Strand',
#  'Unmortgage Leicester Square',
#  'Mortgage The Strand',
#  'Mortgage Marlborough Street',
#  'End turn',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'Mortgage Leicester Square',
#  'Unmortgage The Strand',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage The Strand',
#  'Unmortgage The Strand',
#  'Unmortgage Leicester Square',
#  'Mortgage Leicester Square',
#  "Mortgage King's Cross Station",
#  'End turn',
#  'Unmortgage Regent Street',
#  'Unmortgage Marlborough Street',
#  'Mortgage Oxford Street',
#  'Mortgage Marlborough Street',
#  'Unmortgage Leicester Square',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Mortgage Leicester Square',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Marlborough Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Marlborough Street',
#  'Mortgage Fenchurch St. Station',
#  "Mortgage King's Cross Station",
#  'Unmortgage Leicester Square',
#  'End turn',
#  'Unmortgage Oxford Street',
#  'Purchase Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'Unmortgage Marlborough Street',
#  'Mortgage Leicester Square',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Leicester Square',
#  'End turn',
#  'Mortgage Leicester Square',
#  'End turn',
#  "Unmortgage King's Cross Station",
#  'Mortgage The Strand',
#  'Mortgage Whitechapel Road',
#  'Unmortgage The Strand',
#  "Mortgage King's Cross Station",
#  'End turn',
#  'Unmortgage Leicester Square',
#  'Unmortgage Regent Street',
#  'Mortgage Leicester Square',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'End turn',
#  'Mortgage Marlborough Street',
#  'Purchase Pall Mall',
#  'Mortgage Regent Street',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage The Strand',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage The Strand',
#  'Unmortgage Marlborough Street',
#  'Mortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'Unmortgage Whitechapel Road',
#  'Purchase Vine Street',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Oxford Street',
#  'Mortgage The Strand',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Mortgage Vine Street',
#  'Unmortgage Leicester Square',
#  'Unmortgage Marlborough Street',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'Unmortgage The Strand',
#  'Unmortgage Vine Street',
#  'Mortgage The Strand',
#  'Mortgage Leicester Square',
#  "Mortgage King's Cross Station",
#  'Unmortgage Pall Mall',
#  'Unmortgage The Strand',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  "Unmortgage King's Cross Station",
#  'Mortgage The Strand',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Leicester Square',
#  'Mortgage Pall Mall',
#  'Mortgage Leicester Square',
#  'Mortgage Vine Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage The Strand',
#  'End turn',
#  'Mortgage The Strand',
#  "Mortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Pay 50 to get out of jail',
#  'Mortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Regent Street',
#  "Unmortgage King's Cross Station",
#  'Mortgage Whitechapel Road',
#  'Mortgage Regent Street',
#  'Unmortgage Marlborough Street',
#  "Mortgage King's Cross Station",
#  'Unmortgage Pall Mall',
#  'Unmortgage Vine Street',
#  'Mortgage Vine Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Pall Mall',
#  'Unmortgage Oxford Street',
#  'Mortgage Marlborough Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Marlborough Street',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Unmortgage Vine Street',
#  'Mortgage Vine Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'Mortgage Marlborough Street',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Leicester Square',
#  'End turn',
#  'Mortgage Leicester Square',
#  'Unmortgage Pall Mall',
#  'Unmortgage Leicester Square',
#  'End turn',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Marlborough Street',
#  'Mortgage Leicester Square',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Vine Street',
#  'Unmortgage Leicester Square',
#  'Mortgage Marlborough Street',
#  'Mortgage Leicester Square',
#  'Unmortgage Marlborough Street',
#  "Unmortgage King's Cross Station",
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'Mortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Unmortgage Marlborough Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'Mortgage Vine Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage Oxford Street',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Vine Street',
#  'Mortgage Vine Street',
#  'Unmortgage Leicester Square',
#  'Mortgage Leicester Square',
#  'Unmortgage Vine Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Regent Street',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Marlborough Street',
#  "Mortgage King's Cross Station",
#  'Mortgage Pall Mall',
#  'Unmortgage Leicester Square',
#  'Mortgage Vine Street',
#  'Unmortgage Oxford Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Regent Street',
#  'Unmortgage Pall Mall',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  'Mortgage Leicester Square',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Regent Street',
#  'Mortgage Oxford Street',
#  'End turn',
#  'Unmortgage Leicester Square',
#  'End turn',
#  'Mortgage Leicester Square',
#  'Mortgage Pall Mall',
#  'End turn',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Regent Street',
#  "Mortgage King's Cross Station",
#  'Unmortgage Regent Street',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Mortgage Regent Street',
#  'Unmortgage The Strand',
#  'End turn',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage The Strand',
#  'Unmortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage Vine Street',
#  'Unmortgage Whitechapel Road',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  'End turn',
#  'Mortgage Marlborough Street',
#  "Unmortgage King's Cross Station",
#  'Mortgage Whitechapel Road',
#  "Mortgage King's Cross Station",
#  'Unmortgage Marlborough Street',
#  'Unmortgage Whitechapel Road',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Marlborough Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Vine Street',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Marlborough Street',
#  'Mortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  "Mortgage King's Cross Station",
#  'Unmortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Whitechapel Road',
#  'Mortgage Regent Street',
#  'Unmortgage The Strand',
#  'End turn',
#  'End turn',
#  'Mortgage The Strand',
#  "Unmortgage King's Cross Station",
#  'Mortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  "Mortgage King's Cross Station",
#  "Unmortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'End turn',
#  'Unmortgage Leicester Square',
#  'Mortgage Whitechapel Road',
#  'Mortgage Leicester Square',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Vine Street',
#  'Unmortgage Marlborough Street',
#  "Mortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  'Unmortgage Marlborough Street',
#  'Mortgage Vine Street',
#  'Mortgage Marlborough Street',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Mortgage Pall Mall',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Leicester Square',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Leicester Square',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Oxford Street',
#  'End turn',
#  'Mortgage Oxford Street',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'Unmortgage Marlborough Street',
#  'Unmortgage Oxford Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Oxford Street',
#  'Unmortgage The Strand',
#  'Mortgage The Strand',
#  'Unmortgage Leicester Square',
#  'Mortgage Marlborough Street',
#  "Mortgage King's Cross Station",
#  'Unmortgage Marlborough Street',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'Unmortgage Vine Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Vine Street',
#  'End turn',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Leicester Square',
#  'Unmortgage Leicester Square',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Pay 50 to get out of jail',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Marlborough Street',
#  'End turn',
#  'Mortgage Leicester Square',
#  "Unmortgage King's Cross Station",
#  'Mortgage Marlborough Street',
#  'Unmortgage Fenchurch St. Station',
#  "Mortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Whitechapel Road',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Fenchurch St. Station',
#  "Mortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Use Get Out of Jail Free card',
#  'Mortgage Regent Street',
#  'Unmortgage Regent Street',
#  'End turn',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Mortgage Regent Street',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  'Unmortgage Vine Street',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'Mortgage Vine Street',
#  'Unmortgage The Strand',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage The Strand',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Unmortgage The Strand',
#  'Mortgage Pall Mall',
#  'Mortgage The Strand',
#  'Unmortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  "Mortgage King's Cross Station",
#  'Unmortgage Vine Street',
#  'Mortgage Pall Mall',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Mortgage Vine Street',
#  'Unmortgage Leicester Square',
#  'Mortgage Marlborough Street',
#  'Mortgage Whitechapel Road',
#  'Mortgage Leicester Square',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Vine Street',
#  "Mortgage King's Cross Station",
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Marlborough Street',
#  'End turn',
#  'Mortgage Marlborough Street',
#  'Mortgage Vine Street',
#  'Unmortgage Whitechapel Road',
#  'Unmortgage Vine Street',
#  'Mortgage Whitechapel Road',
#  'Mortgage Vine Street',
#  'Unmortgage Leicester Square',
#  'Mortgage Leicester Square',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Mortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Vine Street',
#  'Mortgage Vine Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Regent Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Vine Street',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Mortgage Vine Street',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  "Unmortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  "Mortgage King's Cross Station",
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Pay 50 to get out of jail',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Pall Mall',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  "Mortgage King's Cross Station",
#  'Unmortgage Vine Street',
#  'End turn',
#  'Mortgage Vine Street',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Unmortgage The Strand',
#  'Mortgage Whitechapel Road',
#  'Mortgage The Strand',
#  'Unmortgage Marlborough Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'Unmortgage Marlborough Street',
#  'Mortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Whitechapel Road',
#  'Mortgage Fenchurch St. Station',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  "Mortgage King's Cross Station",
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Whitechapel Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  "Unmortgage King's Cross Station",
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Unmortgage Marlborough Street',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage Marlborough Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Pay 50 to get out of jail',
#  'Unmortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Unmortgage Leicester Square',
#  'End turn',
#  'End turn',
#  'Mortgage Leicester Square',
#  'Unmortgage Whitechapel Road',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  "Mortgage King's Cross Station",
#  'End turn',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'Unmortgage Vine Street',
#  'Unmortgage The Strand',
#  'Mortgage Vine Street',
#  "Mortgage King's Cross Station",
#  'Unmortgage Oxford Street',
#  'Mortgage Whitechapel Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage The Strand',
#  'Unmortgage Pall Mall',
#  'Mortgage Oxford Street',
#  'Mortgage Pall Mall',
#  "Unmortgage King's Cross Station",
#  'End turn',
#  'Unmortgage Regent Street',
#  'End turn',
#  "Mortgage King's Cross Station",
#  'Unmortgage Leicester Square',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'Mortgage Regent Street',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  'Mortgage Pall Mall',
#  'Unmortgage Oxford Street',
#  'Purchase Old Kent Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Marlborough Street',
#  'Mortgage Old Kent Road',
#  'Mortgage Oxford Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Marlborough Street',
#  'Mortgage Leicester Square',
#  'Buy house on Whitechapel Road',
#  'Unmortgage Leicester Square',
#  'Unmortgage The Strand',
#  'Mortgage Leicester Square',
#  'Unmortgage Marlborough Street',
#  'Mortgage The Strand',
#  'Unmortgage The Strand',
#  'Unmortgage Pall Mall',
#  'Sell house on Whitechapel Road',
#  'End turn',
#  'Mortgage The Strand',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Old Kent Road',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Marlborough Street',
#  'Unmortgage Vine Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Whitechapel Road',
#  'Mortgage Vine Street',
#  'Unmortgage The Strand',
#  'Unmortgage Whitechapel Road',
#  'Mortgage The Strand',
#  'Mortgage Whitechapel Road',
#  "Unmortgage King's Cross Station",
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Whitechapel Road',
#  'Buy house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  'Unmortgage Pall Mall',
#  "Mortgage King's Cross Station",
#  'Mortgage Pall Mall',
#  "Unmortgage King's Cross Station",
#  'Buy house on Old Kent Road',
#  'Mortgage Whitechapel Road',
#  "Mortgage King's Cross Station",
#  'Unmortgage Pall Mall',
#  'Buy house on Whitechapel Road',
#  'Sell house on Whitechapel Road',
#  'Mortgage Pall Mall',
#  'End turn',
#  'Sell house on Old Kent Road',
#  'Buy house on Whitechapel Road',
#  'Sell house on Whitechapel Road',
#  'Buy house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  'End turn',
#  'Buy house on Old Kent Road',
#  'Unmortgage Oxford Street',
#  'Sell house on Old Kent Road',
#  'Buy house on Whitechapel Road',
#  'Sell house on Whitechapel Road',
#  'Mortgage Old Kent Road',
#  'Unmortgage Old Kent Road',
#  'Mortgage Old Kent Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Mortgage Oxford Street',
#  'Buy house on Old Kent Road',
#  'End turn',
#  'Unmortgage Fenchurch St. Station',
#  'Sell house on Old Kent Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'Mortgage Fenchurch St. Station',
#  'End turn',
#  'Buy house on Old Kent Road',
#  'Unmortgage Old Kent Road',
#  'Sell house on Old Kent Road',
#  'Buy house on Whitechapel Road',
#  'Mortgage Old Kent Road',
#  'Sell house on Whitechapel Road',
#  'Unmortgage Old Kent Road',
#  'Mortgage Old Kent Road',
#  'End turn',
#  'Unmortgage Old Kent Road',
#  'Mortgage Old Kent Road',
#  'Buy house on Whitechapel Road',
#  'End turn',
#  'Sell house on Whitechapel Road',
#  'End turn',
#  'Unmortgage Vine Street',
#  'Unmortgage Leicester Square',
#  'End turn',
#  'Mortgage Vine Street',
#  "Unmortgage King's Cross Station",
#  "Mortgage King's Cross Station",
#  'Buy house on Old Kent Road',
#  'Unmortgage Old Kent Road',
#  'Mortgage Leicester Square',
#  'Unmortgage Leicester Square',
#  'Mortgage Leicester Square',
#  'Unmortgage Vine Street',
#  'Unmortgage Whitechapel Road',
#  'Sell house on Old Kent Road',
#  'End turn',
#  'Mortgage Old Kent Road',
#  'Mortgage Vine Street',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Fenchurch St. Station',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Fenchurch St. Station',
#  'Buy house on Old Kent Road',
#  'End turn',
#  'End turn',
#  'Sell house on Old Kent Road',
#  'Unmortgage Old Kent Road',
#  'End turn',
#  'End turn',
#  'Mortgage Old Kent Road',
#  'Buy house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Regent Street',
#  'Mortgage Regent Street',
#  'Unmortgage Vine Street',
#  'Buy house on Old Kent Road',
#  'Mortgage Vine Street',
#  'Sell house on Old Kent Road',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  'Buy house on Old Kent Road',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Sell house on Old Kent Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Buy house on Whitechapel Road',
#  'Sell house on Whitechapel Road',
#  'End turn',
#  'Unmortgage Oxford Street',
#  'Mortgage Oxford Street',
#  'Unmortgage Whitechapel Road',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Buy house on Old Kent Road',
#  'Mortgage Pall Mall',
#  'Unmortgage Old Kent Road',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Buy house on Whitechapel Road',
#  'Buy house on Old Kent Road',
#  'Unmortgage Oxford Street',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Mortgage Oxford Street',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Whitechapel Road',
#  'Use Get Out of Jail Free card',
#  'End turn',
#  'End turn',
#  'Sell house on Old Kent Road',
#  "Mortgage King's Cross Station",
#  'Unmortgage The Strand',
#  'Sell house on Whitechapel Road',
#  'Sell house on Old Kent Road',
#  'Buy house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  'Mortgage Old Kent Road',
#  'Buy house on Old Kent Road',
#  'End turn',
#  'Mortgage The Strand',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  'End turn',
#  'Buy house on Whitechapel Road',
#  'Buy house on Old Kent Road',
#  'End turn',
#  'End turn',
#  'Sell house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  'Pay 50 to get out of jail',
#  'Sell house on Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Pay 50 to get out of jail',
#  'End turn',
#  'End turn',
#  'End turn',
#  'End turn',
#  'Unmortgage Marlborough Street',
#  'Mortgage Marlborough Street',
#  'Unmortgage Old Kent Road',
#  "Unmortgage King's Cross Station",
#  'Buy house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  "Mortgage King's Cross Station",
#  'Unmortgage Pall Mall',
#  'Mortgage Pall Mall',
#  'Buy house on Whitechapel Road',
#  'Buy house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Old Kent Road',
#  'Unmortgage Old Kent Road',
#  'Mortgage Old Kent Road',
#  'Sell house on Whitechapel Road',
#  'Mortgage Whitechapel Road',
#  'Unmortgage Whitechapel Road',
#  'Buy house on Whitechapel Road',
#  'Sell house on Whitechapel Road',
#  'Unmortgage Old Kent Road',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Regent Street',
#  'End turn',
#  'Pay 50 to get out of jail',
#  'Mortgage Old Kent Road',
#  'Buy house on Old Kent Road',
#  'Sell house on Old Kent Road',
#  'Mortgage Regent Street',
#  'Unmortgage Fenchurch St. Station',
#  'End turn',
#  'Buy house on Old Kent Road',
#  'End turn',
#  'End turn',
#  'Unmortgage Regent Street',
#  'Unmortgage Whitechapel Road',
#  'Mortgage Regent Street',
#  "Unmortgage King's Cross Station",
#  'Unmortgage Old Kent Road',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage Pall Mall',
#  'End turn',
#  'Mortgage Whitechapel Road',
#  'Sell house on Old Kent Road',
#  'Unmortgage Vine Street',
#  'Mortgage Old Kent Road',
#  'End turn',
#  'Unmortgage Whitechapel Road',
#  "Mortgage King's Cross Station",
#  'Mortgage Whitechapel Road',
#  'Unmortgage Fenchurch St. Station',
#  'Mortgage Pall Mall',
#  'Buy house on Whitechapel Road',
#  'End turn',
#  'End turn',
#  'Mortgage Fenchurch St. Station',
#  'Unmortgage The Strand',
#  'Unmortgage Old Kent Road',
#  'End turn',
#  'End turn']

# %%
mcts.root.state.agent
# [agent.name, agent.position, agent.money, agent.bankrupt, agent.in_jail, agent.turns_in_jail, 
# agent.double_rolled, agent.num_doubles, agent.jail_cards]
# Out:
# ['Cat', 14, 14.211710999999625, False, True, 1, False, 1, 0, {}]

# %%
mcts.root.state.other_players
# Out:
# [['Vlad', 14, 1717.0, False, False, 11, False, 0, 1, {}]]

# %%
mcts.root.state.properties
# [prop.owner.name, prop.num_houses, prop.hotel, prop.is_mortgaged]
# Out:
# [['Cat', 0, False, False],
#  ['Cat', 1, False, True],
#  ['Vlad', 2, False, False],
#  ['Vlad', 2, False, False],
#  ['Vlad', 0, False, False],
#  ['Cat', 0, False, True],
#  ['Vlad', 0, False, False],
#  ['Vlad', 0, False, False],
#  [None, 0, False, False],
#  ['Cat', 0, False, True],
#  ['Cat', 0, False, False],
#  ['Cat', 0, False, False],
#  [None, 0, False, False],
#  [None, 0, False, False],
#  ['Cat', 0, False, True],
#  [None, 0, False, False],
#  [None, 0, False, False],
#  ['Cat', 0, False, True],
#  ['Cat', 0, False, True],
#  [None, 0, False, False],
#  ['Vlad', 2, False, False],
#  ['Vlad', 0, False, False]]
